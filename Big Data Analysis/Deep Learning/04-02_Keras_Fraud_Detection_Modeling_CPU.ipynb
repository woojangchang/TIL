# %% [markdown]
# # Kaggle 신용카드 사기 검출

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !ls -l '/content/drive/My Drive/Colab Notebooks/datasets/creditCardFraud.zip'
# Out:
# -rw------- 1 root root 69155672 Mar 31 15:04 '/content/drive/My Drive/Colab Notebooks/datasets/creditCardFraud.zip'

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Unzip zip file

# %%
# !unzip '/content/drive/My Drive/Colab Notebooks/datasets/creditCardFraud.zip'
# Out:
# Archive:  /content/drive/My Drive/Colab Notebooks/datasets/creditCardFraud.zip
#   inflating: creditcard.csv

# %% [markdown]
# ### Read Data

# %%
import pandas as pd

DF = pd.read_csv('creditcard.csv')

DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
DF.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# 아마도 표준화 된 데이터

# %%
DF.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
DF.Class.value_counts() / DF.shape[0] * 100
# Out:
# 0    99.827251
# 1     0.172749
# Name: Class, dtype: float64

# %% [markdown]
# 불균형 데이터

# %% [markdown]
# ### Time column 삭제

# %%
DF.drop('Time', axis=1, inplace=True)

DF.shape
# Out:
# (284807, 30)

# %%
X = DF.iloc[:, :-1]
y = DF.iloc[:, -1]

X.shape, y.shape
# Out:
# ((284807, 29), (284807,))

# %% [markdown]
# ### Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,
                                                    stratify=y, random_state=2045)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((199364, 29), (85443, 29), (199364,), (85443,))

# %%
print('학습 데이터 레이블 비율')
print(y_train.value_counts() / y_train.shape[0] * 100)
print('테스트 데이터 레이블 비율')
print(y_test.value_counts() / y_test.shape[0] * 100)
# Out:
# 학습 데이터 레이블 비율
# 0    99.827451
# 1     0.172549
# Name: Class, dtype: float64
# 테스트 데이터 레이블 비율
# 0    99.826785
# 1     0.173215
# Name: Class, dtype: float64

# %% [markdown]
# ## Keras Modeling

# %%
import tensorflow

tensorflow.__version__
# Out:
# '2.5.0'

# %% [markdown]
# ### Model Define

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

ccfd = models.Sequential()

# Hidden Layers
ccfd.add(layers.Dense(128, activation='relu', input_shape=(29,)))
ccfd.add(layers.Dense(64, activation='relu'))
ccfd.add(layers.Dense(32, activation='relu'))

# Output Layer, 이진 분류이므로 하나의 output과 sigmoid activation funcion으로 정의
ccfd.add(layers.Dense(1, activation='sigmoid'))

# %%
ccfd.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               3840
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 14,209
# Trainable params: 14,209
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Complie

# %%
ccfd.compile(loss='binary_crossentropy', # 이진 분류
             optimizer='adam',
             metrics=['Recall']) # 사기를 사기로 검출하는 재현율이 중요한 지표

# %% [markdown]
# ### Model Fit

# %%
# %%time

Hist_ccfd = ccfd.fit(X_train, y_train, epochs=50,
                     batch_size=1024, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 195/195 [==============================] - 3s 9ms/step - loss: 0.0444 - recall: 0.3779 - val_loss: 0.0429 - val_recall: 0.4730
# Epoch 2/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0426 - recall: 0.6105 - val_loss: 0.0126 - val_recall: 0.7365
# Epoch 3/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0080 - recall: 0.7238 - val_loss: 0.0036 - val_recall: 0.8311
# Epoch 4/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0049 - recall: 0.7355 - val_loss: 0.0034 - val_recall: 0.8311
# Epoch 5/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0045 - recall: 0.7529 - val_loss: 0.0031 - val_recall: 0.7230
# Epoch 6/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0419 - recall: 0.6599 - val_loss: 0.0567 - val_recall: 0.5405
# Epoch 7/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0232 - recall: 0.7384 - val_loss: 0.0040 - val_recall: 0.8311
# Epoch 8/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0178 - recall: 0.7209 - val_loss: 0.0040 - val_recall: 0.8176
# Epoch 9/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0088 - recall: 0.7471 - val_loss: 0.0277 - val_recall: 0.7905
# Epoch 10/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0170 - recall: 0.7471 - val_loss: 0.0051 - val_recall: 0.8378
# Epoch 11/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0044 - recall: 0.7820 - val_loss: 0.0044 - val_recall: 0.8041
# Epoch 12/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0037 - recall: 0.7849 - val_loss: 0.0037 - val_recall: 0.8446
# Epoch 13/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0085 - recall: 0.7384 - val_loss: 0.0207 - val_recall: 0.7568
# Epoch 14/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0127 - recall: 0.7849 - val_loss: 0.0038 - val_recall: 0.8378
# Epoch 15/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0036 - recall: 0.7936 - val_loss: 0.0037 - val_recall: 0.8041
# Epoch 16/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0060 - recall: 0.7645 - val_loss: 0.0031 - val_recall: 0.8446
# Epoch 17/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0030 - recall: 0.7965 - val_loss: 0.0034 - val_recall: 0.8514
# Epoch 18/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0031 - recall: 0.7936 - val_loss: 0.0041 - val_recall: 0.8311
# Epoch 19/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0048 - recall: 0.7820 - val_loss: 0.0034 - val_recall: 0.8649
# Epoch 20/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0026 - recall: 0.8081 - val_loss: 0.0030 - val_recall: 0.8311
# Epoch 21/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0026 - recall: 0.8169 - val_loss: 0.0036 - val_recall: 0.7230
# Epoch 22/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0024 - recall: 0.8140 - val_loss: 0.0042 - val_recall: 0.7770
# Epoch 23/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0025 - recall: 0.8256 - val_loss: 0.0031 - val_recall: 0.8649
# Epoch 24/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0024 - recall: 0.8198 - val_loss: 0.0042 - val_recall: 0.8514
# Epoch 25/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0077 - recall: 0.7820 - val_loss: 0.0044 - val_recall: 0.8446
# Epoch 26/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0031 - recall: 0.8110 - val_loss: 0.0042 - val_recall: 0.8311
# Epoch 27/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0087 - recall: 0.8081 - val_loss: 0.0035 - val_recall: 0.8446
# Epoch 28/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0025 - recall: 0.8372 - val_loss: 0.0038 - val_recall: 0.8378
# Epoch 29/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0025 - recall: 0.8459 - val_loss: 0.0036 - val_recall: 0.8311
# Epoch 30/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0022 - recall: 0.8401 - val_loss: 0.0036 - val_recall: 0.8446
# Epoch 31/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0021 - recall: 0.8430 - val_loss: 0.0035 - val_recall: 0.8446
# Epoch 32/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0020 - recall: 0.8488 - val_loss: 0.0034 - val_recall: 0.7905
# Epoch 33/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0021 - recall: 0.8372 - val_loss: 0.0038 - val_recall: 0.8514
# Epoch 34/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0018 - recall: 0.8547 - val_loss: 0.0037 - val_recall: 0.8581
# Epoch 35/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0019 - recall: 0.8517 - val_loss: 0.0036 - val_recall: 0.8311
# Epoch 36/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0019 - recall: 0.8430 - val_loss: 0.0036 - val_recall: 0.8649
# Epoch 37/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0021 - recall: 0.8372 - val_loss: 0.0038 - val_recall: 0.8649
# Epoch 38/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0021 - recall: 0.8517 - val_loss: 0.0036 - val_recall: 0.7770
# Epoch 39/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0020 - recall: 0.8488 - val_loss: 0.0038 - val_recall: 0.8108
# Epoch 40/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0020 - recall: 0.8459 - val_loss: 0.0049 - val_recall: 0.8176
# Epoch 41/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0083 - recall: 0.7820 - val_loss: 0.0050 - val_recall: 0.8311
# Epoch 42/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0042 - recall: 0.8256 - val_loss: 0.0040 - val_recall: 0.8446
# Epoch 43/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0022 - recall: 0.8285 - val_loss: 0.0037 - val_recall: 0.8581
# Epoch 44/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0018 - recall: 0.8547 - val_loss: 0.0036 - val_recall: 0.8649
# Epoch 45/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0017 - recall: 0.8692 - val_loss: 0.0037 - val_recall: 0.8581
# Epoch 46/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0016 - recall: 0.8663 - val_loss: 0.0039 - val_recall: 0.8446
# Epoch 47/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0016 - recall: 0.8692 - val_loss: 0.0039 - val_recall: 0.8446
# Epoch 48/50
# 195/195 [==============================] - 1s 7ms/step - loss: 0.0017 - recall: 0.8488 - val_loss: 0.0043 - val_recall: 0.8514
# Epoch 49/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0017 - recall: 0.8779 - val_loss: 0.0044 - val_recall: 0.8649
# Epoch 50/50
# 195/195 [==============================] - 1s 6ms/step - loss: 0.0014 - recall: 0.8721 - val_loss: 0.0044 - val_recall: 0.8581
# CPU times: user 1min 27s, sys: 5.4 s, total: 1min 32s
# Wall time: 1min 6s

# %% [markdown]
# ### 학습 결과 시각화

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_ccfd.history['loss'])+1)

plt.figure(figsize=(9, 6))
plt.plot(epochs, Hist_ccfd.history['loss'])
plt.plot(epochs, Hist_ccfd.history['val_loss'])
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %%
epochs = range(1, len(Hist_ccfd.history['recall'])+1)

plt.figure(figsize=(9, 6))
plt.plot(epochs, Hist_ccfd.history['recall'])
plt.plot(epochs, Hist_ccfd.history['val_recall'])
plt.title('Training & Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'])
plt.grid()
plt.show()

# %% [markdown]
# ### Model Evaluate

# %%
loss, recall = ccfd.evaluate(X_test, y_test)

print(f'Loss : {loss:.5f}')
print(f'Recall : {recall:.5f}')
# Out:
# 2671/2671 [==============================] - 3s 1ms/step - loss: 0.0044 - recall: 0.8581
# Loss : 0.00441
# Recall : 0.85811

# %% [markdown]
# ### Model Predict

# %%
y_hat = ccfd.predict_classes(X_test)

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, y_hat)
# Out:
# array([[85281,    14],
#        [   21,   127]])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

print(accuracy_score(y_test, y_hat))
print(precision_score(y_test, y_hat))
print(recall_score(y_test, y_hat))
# Out:
# 0.9995903701883126
# 0.900709219858156
# 0.8581081081081081
