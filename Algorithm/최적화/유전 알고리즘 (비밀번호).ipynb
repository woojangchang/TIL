# %% [markdown]
# https://tasddc.tistory.com/104

# %% [markdown]
# # 비밀번호 뚫기
# - 알파벳 대소문자와 숫자로 이루어진 2~10자리의 비밀번호를 유전 알고리즘으로 뚫기

# %%
import random
import string

# %%
# 비밀번호의 길이만큼 랜덤으로 생성
def generate_word(length):
    result = ""
    x = "".join(random.sample(string.ascii_letters + string.digits, k=length))
    return x

# %%
password = generate_word(length=10)
password
# Out:
# '5cyNLCWrkR'

# %%
# 첫번째 세대가 태어남. 
def generate_population(size, min_len, max_len):
    population = [] # 빈 리스트 생성
    
    for i in range(size): # size 만큼 loop를 돌면서
        # 최소 길이부터 최대 길이까지 밸런스하게 랜덤으로 생성한다.
        length = i % (max_len - min_len + 1) + min_len
        population.append(generate_word(length))
        
    return population

# %%
# 최소길이가 2이고 최대길이가 10인 문자열을 100개 생성
min_len = 2
max_len = 10
pop = generate_population(size=100, min_len=min_len, max_len=max_len) 
print(pop)
# Out:
# ['vn', 'Jsq', 'AcwE', 'Fsb6B', '78BoH2', 'qebcfpg', 'sg7oyReB', 'IaVKxujTy', 'zaKxt2yRfi', 'fe', 'rPs', 'mcY9', 'FI4W6', 'k4Qqov', 'N9WFqVZ', 'iul7tIU5', '5NWI981um', 'z2ZnMgBNRe', 'HI', '5w3', 'slX9', '8kgDH', 'YJbrXP', 'h7g2Wo8', 'ORDbnNcA', 'lnQWaxVAy', 'rw7JV1MtKH', 'Qw', 'JLp', 'HPwr', 'gCxpd', 'F6DnAs', 'YaULVBm', '7LWSwPhg', '1M7pqavZU', 'VAGWw7vfQR', 'jx', 'cfu', 'GuBo', 'ezt2J', 'G3E6hN', 'ZlCbniN', 'GpsT6uJv', 'WUSC5o6HT', '2POcyHnvtx', 'Cy', 'ihJ', 'HvJe', '8kFH9', 'Los7R2', 'xcg6FjB', 'jF4OtA5W', 'WDUGyYJ5Z', 'rbs5ypcimu', 'UO', 'WFL', 'wq5H', 'Iu6TK', 'HTfROV', 'FrJT6Lz', 'TFgMeUtC', 'dkJzS2HOL', 'BNkejUbDh9', 'iD', 'ibW', 'ZQqc', 'UlQAC', 'tHX9vr', 'G7NBEt0', 'XMEz92kJ', '8gfuwo5eE', 'U4vAFZDgGJ', 'mW', 'jHS', 'yiHT', 'ERtxW', 'O6xWAB', 'Hm694Zz', '8SVuDJb1', 'rkRwp2vMO', 'vpeG9knXQM', 'Fy', 'rTO', '0gsH', 'mywlT', 'LD5n0H', '6xCHW8b', '8XaZyNsj', 'cdlSPoCwj', '9ipJUzNYR2', 'Xc', 'mUZ', '8TXI', 'wxCmf', 'YTdINw', '02EfCPw', '1b0QfDqW', 'B6IifadqK', 'RuDH32epLt', 'DK']

# %%
# fitness 측정 (성능 측정 단계)
def fitness(password, test_word):
    score = 0 # 초기 점수는 0점으로 초기화.

    # 길이가 다르면 0점 return
    if len(password) != len(test_word):
        return score
    
    # 길이가 같으면 0.5점을 더해준다.
    len_score = 0.5
    score += len_score

    # 설정한 비밀번호와 비교하여 해당 문자열이 있는지 있으면 1점을 더해준다.
    for i in range(len(password)):
        if password[i] == test_word[i]:
            score += 1
    
    # 백점 만점에 몇점인지 계산한다. (성능 측정)
    return score / (len(password) + len_score) * 100

# %%
print(fitness('abcdE', 'abcde')) # 설정한 비밀번호와 비교하였을 때 점수는 81.81점
# Out:
# 81.81818181818183

# %%
def compute_performance(population, password):
    performance_list = [] # population을 점수 순서대로 정렬하기 위해서 list 생성.
    for individual in population:
        # 각각의 자식들의 점수를 측정한다.
        score = fitness(password, individual)

        # 비밀번호의 길이를 예측할 수 있다.
        if score > 0: # 점수가 0보다 크다는 뜻은 비밀번호의 길이는 맞췄다는 의미이다.
            pred_len = len(individual) # 예상 길이를 pred_len 변수에 저장한다.
        performance_list.append([individual, score])

    # list를 정렬하는데 key(점수)를 기준으로 내림차순으로 정렬한다.
    population_sorted = sorted(performance_list, key=lambda x: x[1], reverse=True)
    return population_sorted, pred_len

# %%
# 살아남은 아이들을 select할 함수이다.
def select_survivors(population_sorted, best_sample, lucky_few, password_len):
    next_generation = []

    # best_sample 수 만큼 뽑아서 다음 세대로 보낸다.
    for i in range(best_sample):
        if population_sorted[i][1] > 0:
            next_generation.append(population_sorted[i][0])
    
    # 랜덤으로 운이 좋은 자식들을 살린다.
    lucky_survivors = random.sample(population_sorted, k=lucky_few)
    for I in lucky_survivors:
        next_generation.append(I[0])

    # 다음 세대의 아이들의 수가 부족할 수 있기 때문에 랜덤으로 생성하여 채워넣는 부분이다.
    if len(next_generation) < best_sample + lucky_few:
        next_generation.append(generate_word(length=password_len))

    # 다음 세대의 아이들 리스트를 랜덤한 순으로 섞는다.
    random.shuffle(next_generation)
    return next_generation

# %%
pop_sorted, pred_len = compute_performance(pop, password)
print(pop_sorted)
# 100명의 자식들 중에서 성능이 우수한 20명과 운이 좋은 20명을 선발한다.
survivors = select_survivors(pop_sorted, best_sample=20, lucky_few=20, password_len=pred_len)

print('password length must be %s' % pred_len)
print(survivors)
# Out:
# [['VAGWw7vfQR', 14.285714285714285], ['zaKxt2yRfi', 4.761904761904762], ['z2ZnMgBNRe', 4.761904761904762], ['rw7JV1MtKH', 4.761904761904762], ['2POcyHnvtx', 4.761904761904762], ['rbs5ypcimu', 4.761904761904762], ['BNkejUbDh9', 4.761904761904762], ['U4vAFZDgGJ', 4.761904761904762], ['vpeG9knXQM', 4.761904761904762], ['9ipJUzNYR2', 4.761904761904762], ['RuDH32epLt', 4.761904761904762], ['vn', 0], ['Jsq', 0], ['AcwE', 0], ['Fsb6B', 0], ['78BoH2', 0], ['qebcfpg', 0], ['sg7oyReB', 0], ['IaVKxujTy', 0], ['fe', 0], ['rPs', 0], ['mcY9', 0], ['FI4W6', 0], ['k4Qqov', 0], ['N9WFqVZ', 0], ['iul7tIU5', 0], ['5NWI981um', 0], ['HI', 0], ['5w3', 0], ['slX9', 0], ['8kgDH', 0], ['YJbrXP', 0], ['h7g2Wo8', 0], ['ORDbnNcA', 0], ['lnQWaxVAy', 0], ['Qw', 0], ['JLp', 0], ['HPwr', 0], ['gCxpd', 0], ['F6DnAs', 0], ['YaULVBm', 0], ['7LWSwPhg', 0], ['1M7pqavZU', 0], ['jx', 0], ['cfu', 0], ['GuBo', 0], ['ezt2J', 0], ['G3E6hN', 0], ['ZlCbniN', 0], ['GpsT6uJv', 0], ['WUSC5o6HT', 0], ['Cy', 0], ['ihJ', 0], ['HvJe', 0], ['8kFH9', 0], ['Los7R2', 0], ['xcg6FjB', 0], ['jF4OtA5W', 0], ['WDUGyYJ5Z', 0], ['UO', 0], ['WFL', 0], ['wq5H', 0], ['Iu6TK', 0], ['HTfROV', 0], ['FrJT6Lz', 0], ['TFgMeUtC', 0], ['dkJzS2HOL', 0], ['iD', 0], ['ibW', 0], ['ZQqc', 0], ['UlQAC', 0], ['tHX9vr', 0], ['G7NBEt0', 0], ['XMEz92kJ', 0], ['8gfuwo5eE', 0], ['mW', 0], ['jHS', 0], ['yiHT', 0], ['ERtxW', 0], ['O6xWAB', 0], ['Hm694Zz', 0], ['8SVuDJb1', 0], ['rkRwp2vMO', 0], ['Fy', 0], ['rTO', 0], ['0gsH', 0], ['mywlT', 0], ['LD5n0H', 0], ['6xCHW8b', 0], ['8XaZyNsj', 0], ['cdlSPoCwj', 0], ['Xc', 0], ['mUZ', 0], ['8TXI', 0], ['wxCmf', 0], ['YTdINw', 0], ['02EfCPw', 0], ['1b0QfDqW', 0], ['B6IifadqK', 0], ['DK', 0]]
# password length must be 10
# ['B6IifadqK', 'z2ZnMgBNRe', 'rw7JV1MtKH', '9ipJUzNYR2', 'mywlT', 'fe', 'dkJzS2HOL', 'BNkejUbDh9', 'h7g2Wo8', 'Fy', 'rbs5ypcimu', 'U4vAFZDgGJ', 'G7NBEt0', 'djiN8KpHJ1', 'RuDH32epLt', 'FrJT6Lz', 'zaKxt2yRfi', '8kgDH', 'Iu6TK', 'BNkejUbDh9', '2POcyHnvtx', 'Cy', 'AcwE', 'VAGWw7vfQR', 'zaKxt2yRfi', 'vpeG9knXQM', 'xcg6FjB', 'ZlCbniN', 'RuDH32epLt', 'cdlSPoCwj', 'VAGWw7vfQR', 'YaULVBm']

# %%
# Create Children (살아남은 아이들을 교배시킨다.)
# individual1 : 엄마
# individual2 : 아빠
def create_child(individual1, individual2):
    child = ''
    # 더 짧은 길이의 유전자에 맞춰서 생성.
    min_len_ind = min(len(individual1), len(individual2))
    for i in range(min_len_ind):
        if (int(100*random.random()) < 50): # 50%의 확률로 엄마의 유전자를 획득
            child += individual1[i]
        else:
            child += individual2[i] # 나머지 50% 확률로 아빠의 유전자를 획득
    return child

def create_children(parents, n_child):
    next_population = []
    for i in range(int(len(parents)/2)):
        for j in range(n_child):
            next_population.append(create_child(parents[i], parents[len(parents) -1 -i]))
    return next_population

# %%
# survivors : 성능이 좋은아이들 20명, 운이좋은 아이들 20명 이므로 길이는 40
# 살아남은 아이들이 각각 5명씩 아이를 낳는다.
# 40명의 부모 = 20커플
# 5명씩 아이를 낳으면 20 X 5 = 100명
children = create_children(survivors, 5)
print("---------------children---------------\n", children)
# Out:
# ---------------children---------------
#  ['BaULfBm', 'BaIiVBd', 'YaULfBd', 'B6IifBm', 'B6Uifad', 'z2GWwgBfRe', 'zAZWMgvNRR', 'VAGnw7BNQR', 'zAZnM7BfRR', 'V2GWM7vfRR', 'cd7SPoMtj', 'rwlJVoCwj', 'rdlSV1CtK', 'cd7SV1Cwj', 'cdlSV1MtK', '9upJ3zNYR2', 'RipJ3zeYLt', '9ipJ3zepLt', '9uDHU2NpL2', '9uDH3zeYRt', 'ZlwlT', 'ZywlT', 'mlwbT', 'ZywbT', 'ZlwlT', 'xe', 'xc', 'xc', 'xe', 'fe', 'vpeGSknXL', 'vpJz92nOQ', 'vpez92nXQ', 'dpJGS2HXQ', 'dkezSknXQ', 'zNKxt2yRfi', 'BaKejUyDf9', 'BakejUyDh9', 'zaKetUbRh9', 'BNkej2yDh9', 'hAg2Wov', 'h7gWWo8', 'hAg2wov', 'VAGWwov', 'V7gWW78', 'Ay', 'Fy', 'Ac', 'Ay', 'Fc', 'ry', 'Cy', 'rb', 'rb', 'Cy', 'UPOAFHDgGJ', 'U4OcFZnvtJ', '2POAFZngGx', '2PvcyZngtJ', '2POcyZDvGJ', 'G7keEt0', 'G7kBjU0', 'G7keEU0', 'BNNejtb', 'BNNBEtb', 'duiNK', 'Ij6TK', 'djiNK', 'IuiTK', 'du6NK', '8uDHH', '8ugDH', '8ugD3', 'RkgHH', 'RkgH3', 'FrKxt2z', 'zrJxt2y', 'zaKTtLy', 'zaJxtLz', 'zrKT6Ly']

# %%
# 돌연변이 생성
def mutate_word(word):
    # 비밀번호에서 임의의 idx 값을 추출한다
    idx = int (random.random() * len(word)) 
    
    # 추출한 idx 값에 랜덤한 값을 넣는다.
    if (idx == 0):
        word = random.choice(string.ascii_letters + string.digits) + word[1:]
    else:
        word = word[:idx] + random.choice(string.ascii_letters + string.digits) + word[idx+1:]
    return word

# 100명의 아이들 중에서 10% 확률로 돌연변이를 생성한다.
def mutate_population(population, chance_of_mutation):
    for i in range(len(population)):
        if random.random() * 100 < chance_of_mutation:
            population[i] = mutate_word(population[i])
    return population

# %%
if __name__ == "__main__":

    # 비밀번호의 최대, 최소 자릿수를 지정해놓음.
    password = 'T4As2Dc39i'
    min_len = 2
    max_len = 10
    n_generation = 300
    population = 100
    best_sample = 20
    lucky_few = 20
    n_child = 5
    chance_of_mutation = 10

    pop = generate_population(size=population, min_len=min_len, max_len=max_len)

    # 총 300 세대를 생성하면서 반복한다.
    for g in range(n_generation):
        
        pop_sorted, pred_len = compute_performance(population=pop, password=password)

        # pop_sorted에서 첫 번째의 점수가 100점이면 비밀번호 찾음.  
        if int(pop_sorted[0][1]) == 100:
            print("SUCCESS! The password is %s" % (pop_sorted[0][0]))
            break
    
        survivors = select_survivors(population_sorted=pop_sorted, best_sample=best_sample, lucky_few=lucky_few, password_len=pred_len)

        children = create_children(parents=survivors, n_child=n_child)

        new_generation = mutate_population(population=children, chance_of_mutation=chance_of_mutation)

        pop = new_generation

        print("===========%sth generation==========" %(g+1))
        print(pop_sorted[0])
# Out:
# ===========1th generation==========
# ['tYpmL9rWai', 14.285714285714285] 80
# ===========2th generation==========
# ['WU4eu9GQze', 4.761904761904762] 65
# ===========3th generation==========
# ['y41eujRhfX', 14.285714285714285] 65
# ===========4th generation==========
# ['y41eujGhzX', 14.285714285714285] 75
# ===========5th generation==========
# ['y41eujihfe', 14.285714285714285] 100
# ===========6th generation==========
# ['yV1eu9chfX', 14.285714285714285] 100
# ===========7th generation==========
# ['yV1eu9chfX', 14.285714285714285] 100
# ===========8th generation==========
# ['yV1eujcQfe', 14.285714285714285] 100
# ===========9th generation==========
# ['yV1eu9chfX', 14.285714285714285] 100
# ===========10th generation==========
# ['yV1eu9cQfX', 14.285714285714285] 100
# ===========11th generation==========
# ['yV1eu9cdfX', 14.285714285714285] 100
# ===========12th generation==========
# ['yV1eu9chfX', 14.285714285714285] 100
# ===========13th generation==========
# ['yV1eu9cQfX', 14.285714285714285] 100
# ===========14th generation==========
# ['yVAeu9chfe', 23.809523809523807] 100
# ===========15th generation==========
# ['yVAeu9chfe', 23.809523809523807] 100
# ===========16th generation==========
# ['yVAeuHcQfe', 23.809523809523807] 100
# ===========17th generation==========
# ['yVAeu9chfX', 23.809523809523807] 100
# ===========18th generation==========
# ['yVAeuCchfX', 23.809523809523807] 100
# ===========19th generation==========
# ['yVAeuHchfX', 23.809523809523807] 100
# ===========20th generation==========
# ['yVAeu9cQfX', 23.809523809523807] 100
# ===========21th generation==========
# ['yVAeu9chfX', 23.809523809523807] 100
# ===========22th generation==========
# ['yVAeuHchfe', 23.809523809523807] 100
# ===========23th generation==========
# ['yVAeu9cQfe', 23.809523809523807] 100
# ===========24th generation==========
# ['yVAeuHcQfX', 23.809523809523807] 100
# ===========25th generation==========
# ['yVAeu9cQfe', 23.809523809523807] 100
# ===========26th generation==========
# ['yVAeu9cQfe', 23.809523809523807] 100
# ===========27th generation==========
# ['yVAeu9cQfX', 23.809523809523807] 100
# ===========28th generation==========
# ['yVAeuHcQfe', 23.809523809523807] 100
# ===========29th generation==========
# ['yzAeu9cOfX', 23.809523809523807] 100
# ===========30th generation==========
# ['yVAeuHcQfX', 23.809523809523807] 100
# ===========31th generation==========
# ['yVAeuHcQfe', 23.809523809523807] 100
# ===========32th generation==========
# ['yVAeu9cQfX', 23.809523809523807] 100
# ===========33th generation==========
# ['yzAeuHcQfH', 23.809523809523807] 100
# ===========34th generation==========
# ['yzAeuHcQfX', 23.809523809523807] 100
# ===========35th generation==========
# ['yvAeu9cOfX', 23.809523809523807] 100
# ===========36th generation==========
# ['azAeuHcQfe', 23.809523809523807] 100
# ===========37th generation==========
# ['yVAeuHcQfe', 23.809523809523807] 100
# ===========38th generation==========
# ['aVAeuHcQfX', 23.809523809523807] 100
# ===========39th generation==========
# ['yVAeTHcQfX', 23.809523809523807] 100
# ===========40th generation==========
# ['yVAePHcQfI', 23.809523809523807] 100
# ===========41th generation==========
# ['yVAePHcQfe', 23.809523809523807] 100
# ===========42th generation==========
# ['yWAeuHcOfX', 23.809523809523807] 100
# ===========43th generation==========
# ['y3AeuHcQfX', 23.809523809523807] 100
# ===========44th generation==========
# ['yMAeuHcQfX', 23.809523809523807] 100
# ===========45th generation==========
# ['y8AeuHcQfX', 23.809523809523807] 100
# ===========46th generation==========
# ['yzAeuHcQfe', 23.809523809523807] 100
# ===========47th generation==========
# ['yzAeuHcQfX', 23.809523809523807] 100
# ===========48th generation==========
# ['yVAePHcQfe', 23.809523809523807] 100
# ===========49th generation==========
# ['yMAeukcQfX', 23.809523809523807] 100
# ===========50th generation==========
# ['yMAeukcQwX', 23.809523809523807] 100
# ===========51th generation==========
# ['yzAeukcQfe', 23.809523809523807] 100
# ===========52th generation==========
# ['yMAeuHcQfX', 23.809523809523807] 100
# ===========53th generation==========
# ['yzAeukcQfX', 23.809523809523807] 100
# ===========54th generation==========
# ['yzAPuHcQfe', 23.809523809523807] 100
# ===========55th generation==========
# ['yzAeuHcQfX', 23.809523809523807] 100
# ===========56th generation==========
# ['yzAeuHcQfX', 23.809523809523807] 100
# ===========57th generation==========
# ['yzA4uHcQwX', 23.809523809523807] 100
# ===========58th generation==========
# ['yzA4PHcQfX', 23.809523809523807] 100
# ===========59th generation==========
# ['yvAeuHcQwX', 23.809523809523807] 100
# ===========60th generation==========
# ['yMAePHcQfX', 23.809523809523807] 100
# ===========61th generation==========
# ['yzAeukcQwX', 23.809523809523807] 100
# ===========62th generation==========
# ['yMAeukcQwX', 23.809523809523807] 100
# ===========63th generation==========
# ['y4A4PkcQwX', 33.33333333333333] 100
# ===========64th generation==========
# ['yMA4uDcQwD', 33.33333333333333] 100
# ===========65th generation==========
# ['y4A4ukcQwX', 33.33333333333333] 100
# ===========66th generation==========
# ['yMAe2DcQwD', 42.857142857142854] 100
# ===========67th generation==========
# ['y4A4uDcQfX', 42.857142857142854] 100
# ===========68th generation==========
# ['y4AePDcQwD', 42.857142857142854] 100
# ===========69th generation==========
# ['y4Ae2DcQfX', 52.38095238095239] 100
# ===========70th generation==========
# ['y4A42DcQwX', 52.38095238095239] 100
# ===========71th generation==========
# ['y4Ae2DcQwX', 52.38095238095239] 100
# ===========72th generation==========
# ['y4A42DcQfX', 52.38095238095239] 100
# ===========73th generation==========
# ['y4A42DcQfX', 52.38095238095239] 100
# ===========74th generation==========
# ['y4A42DcQwX', 52.38095238095239] 100
# ===========75th generation==========
# ['W4Ae2DcQzX', 52.38095238095239] 100
# ===========76th generation==========
# ['y4A42DcQwX', 52.38095238095239] 100
# ===========77th generation==========
# ['y4Ae2DcQwX', 52.38095238095239] 100
# ===========78th generation==========
# ['y4Ae2DcQwX', 52.38095238095239] 100
# ===========79th generation==========
# ['y4Ae2DcQwX', 52.38095238095239] 100
# ===========80th generation==========
# ['y4Ae2DcQAX', 52.38095238095239] 100
# ===========81th generation==========
# ['y4Ae2DcQwX', 52.38095238095239] 100
# ===========82th generation==========
# ['y4Ae2DcQNX', 52.38095238095239] 100
# ===========83th generation==========
# ['y4Ae2DcQNX', 52.38095238095239] 100
# ===========84th generation==========
# ['y4Ae2DcQwX', 52.38095238095239] 100
# ===========85th generation==========
# ['y4Ae2DcQwX', 52.38095238095239] 100
# ===========86th generation==========
# ['y4Ae2DcQwX', 52.38095238095239] 100
# ===========87th generation==========
# ['y4Ae2DcQwX', 52.38095238095239] 100
# ===========88th generation==========
# ['y4Ae2DcH3X', 52.38095238095239] 100
# ===========89th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========90th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========91th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========92th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========93th generation==========
# ['P4Ae2Dc3wX', 61.904761904761905] 100
# ===========94th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========95th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========96th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========97th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========98th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========99th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========100th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========101th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========102th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========103th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========104th generation==========
# ['T4Ae2Dc3wX', 71.42857142857143] 100
# ===========105th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========106th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========107th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========108th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========109th generation==========
# ['y4Ag2Dc3wX', 61.904761904761905] 100
# ===========110th generation==========
# ['y4Ag2Dc3wX', 61.904761904761905] 100
# ===========111th generation==========
# ['y4Ag2Dc3HX', 61.904761904761905] 100
# ===========112th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========113th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========114th generation==========
# ['y4Ae2Dc3wX', 61.904761904761905] 100
# ===========115th generation==========
# ['04Ae2Dc3wX', 61.904761904761905] 100
# ===========116th generation==========
# ['B4Ae2Dc3wX', 61.904761904761905] 100
# ===========117th generation==========
# ['T4Ag2Dc3wX', 71.42857142857143] 100
# ===========118th generation==========
# ['T4Ag2Dc3wX', 71.42857142857143] 100
# ===========119th generation==========
# ['T4Ag2Dc3wX', 71.42857142857143] 100
# ===========120th generation==========
# ['T4Ae2Dc3wX', 71.42857142857143] 100
# ===========121th generation==========
# ['T4Ae2Dc3wX', 71.42857142857143] 100
# ===========122th generation==========
# ['T4Ae2Dc3Q9', 71.42857142857143] 100
# ===========123th generation==========
# ['T4Ae2Dc3wX', 71.42857142857143] 100
# ===========124th generation==========
# ['T4Ag2Dc3Q9', 71.42857142857143] 100
# ===========125th generation==========
# ['T4Ae2Dc3w9', 71.42857142857143] 100
# ===========126th generation==========
# ['T4Ae2Dc3wX', 71.42857142857143] 100
# ===========127th generation==========
# ['T4Ag2Dc3wX', 71.42857142857143] 100
# ===========128th generation==========
# ['T4Ag2Dc3wX', 71.42857142857143] 100
# ===========129th generation==========
# ['T4Ar2Dc3QX', 71.42857142857143] 100
# ===========130th generation==========
# ['T4Ar2Dc3q9', 71.42857142857143] 100
# ===========131th generation==========
# ['T4Ae2Dc3wX', 71.42857142857143] 100
# ===========132th generation==========
# ['T4Ar2Dc3Q9', 71.42857142857143] 100
# ===========133th generation==========
# ['T4Ar2Dc3Q9', 71.42857142857143] 100
# ===========134th generation==========
# ['T4Ag2Dc3wX', 71.42857142857143] 100
# ===========135th generation==========
# ['T4Ag2Dc3w9', 71.42857142857143] 100
# ===========136th generation==========
# ['T4Ar2Dc3QX', 71.42857142857143] 100
# ===========137th generation==========
# ['T4Ag2Dc3QX', 71.42857142857143] 100
# ===========138th generation==========
# ['T4Ag2Dc3Q9', 71.42857142857143] 100
# ===========139th generation==========
# ['T4Ag2Dc3QX', 71.42857142857143] 100
# ===========140th generation==========
# ['T4Ag2Dc3QX', 71.42857142857143] 100
# ===========141th generation==========
# ['T4Ag2Dc3QX', 71.42857142857143] 100
# ===========142th generation==========
# ['T4Ag2Dc3QX', 71.42857142857143] 100
# ===========143th generation==========
# ['T4Ag2Dc39X', 80.95238095238095] 100
# ===========144th generation==========
# ['T4A02Dc39X', 80.95238095238095] 100
# ===========145th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========146th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========147th generation==========
# ['T4Ag2Dc39X', 80.95238095238095] 100
# ===========148th generation==========
# ['T4Ag2Dc39X', 80.95238095238095] 100
# ===========149th generation==========
# ['T4Ag2Dc39X', 80.95238095238095] 100
# ===========150th generation==========
# ['T4Ag2Dc39X', 80.95238095238095] 100
# ===========151th generation==========
# ['T4A02Dc399', 80.95238095238095] 100
# ===========152th generation==========
# ['T4Ag2Dc39X', 80.95238095238095] 100
# ===========153th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========154th generation==========
# ['T4Ag2Dc39X', 80.95238095238095] 100
# ===========155th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========156th generation==========
# ['T4Ag2Dc39X', 80.95238095238095] 100
# ===========157th generation==========
# ['T4Ag2Dc39X', 80.95238095238095] 100
# ===========158th generation==========
# ['T4Ag2Dc39X', 80.95238095238095] 100
# ===========159th generation==========
# ['T4Ag2Dc39X', 80.95238095238095] 100
# ===========160th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========161th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========162th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========163th generation==========
# ['T4Ag2Dc39X', 80.95238095238095] 100
# ===========164th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========165th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========166th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========167th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========168th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========169th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========170th generation==========
# ['T4Ag2Dc39X', 80.95238095238095] 100
# ===========171th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========172th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========173th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========174th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========175th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========176th generation==========
# ['T4Ag2Dc39K', 80.95238095238095] 100
# ===========177th generation==========
# ['T4Ag2Dc397', 80.95238095238095] 100
# ===========178th generation==========
# ['T4Ag2Dc39q', 80.95238095238095] 100
# ===========179th generation==========
# ['T4Ag2Dc39q', 80.95238095238095] 100
# ===========180th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========181th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========182th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========183th generation==========
# ['T4Ag2Dc397', 80.95238095238095] 100
# ===========184th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========185th generation==========
# ['T4Ag2Dc39q', 80.95238095238095] 100
# ===========186th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========187th generation==========
# ['T4Ag2Dc392', 80.95238095238095] 100
# ===========188th generation==========
# ['T4Ag2Dc39H', 80.95238095238095] 100
# ===========189th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========190th generation==========
# ['T4Ag2Dc392', 80.95238095238095] 100
# ===========191th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========192th generation==========
# ['T4Ag2Dc39n', 80.95238095238095] 100
# ===========193th generation==========
# ['T4Ag2Dc39n', 80.95238095238095] 100
# ===========194th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========195th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========196th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========197th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========198th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========199th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========200th generation==========
# ['T4Ag2Dc39n', 80.95238095238095] 100
# ===========201th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========202th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========203th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========204th generation==========
# ['T4A52Dc39n', 80.95238095238095] 100
# ===========205th generation==========
# ['T4Ag2Dc39S', 80.95238095238095] 100
# ===========206th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========207th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========208th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========209th generation==========
# ['T4Ag2Dc39S', 80.95238095238095] 100
# ===========210th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========211th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========212th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========213th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========214th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========215th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========216th generation==========
# ['T4AV2Dc399', 80.95238095238095] 100
# ===========217th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========218th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========219th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========220th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========221th generation==========
# ['T4AV2Dc399', 80.95238095238095] 100
# ===========222th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========223th generation==========
# ['T4Ag2Dc39S', 80.95238095238095] 100
# ===========224th generation==========
# ['T4AV2Dc399', 80.95238095238095] 100
# ===========225th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========226th generation==========
# ['T4AV2Dc399', 80.95238095238095] 100
# ===========227th generation==========
# ['T4AV2Dc399', 80.95238095238095] 100
# ===========228th generation==========
# ['T4AV2Dc399', 80.95238095238095] 100
# ===========229th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========230th generation==========
# ['T4AV2Dc399', 80.95238095238095] 100
# ===========231th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========232th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========233th generation==========
# ['T4A82Dc399', 80.95238095238095] 100
# ===========234th generation==========
# ['T4AV2Dc399', 80.95238095238095] 100
# ===========235th generation==========
# ['T4Ag2Dc399', 80.95238095238095] 100
# ===========236th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========237th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========238th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========239th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========240th generation==========
# ['T4Ag2Dc39i', 90.47619047619048] 100
# ===========241th generation==========
# ['T4A72Dc39i', 90.47619047619048] 100
# ===========242th generation==========
# ['T4Ag2Dc39i', 90.47619047619048] 100
# ===========243th generation==========
# ['T4Ag2Dc39i', 90.47619047619048] 100
# ===========244th generation==========
# ['T4Ag2Dc39i', 90.47619047619048] 100
# ===========245th generation==========
# ['T4Ag2Dc39i', 90.47619047619048] 100
# ===========246th generation==========
# ['T4Ag2Dc39i', 90.47619047619048] 100
# ===========247th generation==========
# ['T4Ag2Dc39i', 90.47619047619048] 100
# ===========248th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========249th generation==========
# ['T4Ag2Dc39i', 90.47619047619048] 100
# ===========250th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========251th generation==========
# ['T4Ag2Dc39i', 90.47619047619048] 100
# ===========252th generation==========
# ['T4Ag2Dc39i', 90.47619047619048] 100
# ===========253th generation==========
# ['T4Ag2Dc39i', 90.47619047619048] 100
# ===========254th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========255th generation==========
# ['T4Ag2Dc39i', 90.47619047619048] 100
# ===========256th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========257th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========258th generation==========
# ['T4AK2Dc39i', 90.47619047619048] 100
# ===========259th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========260th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========261th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========262th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========263th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========264th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========265th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========266th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========267th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========268th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========269th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========270th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========271th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========272th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========273th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========274th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========275th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========276th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========277th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# ===========278th generation==========
# ['T4A82Dc39i', 90.47619047619048] 100
# SUCCESS! The password is T4As2Dc39i
